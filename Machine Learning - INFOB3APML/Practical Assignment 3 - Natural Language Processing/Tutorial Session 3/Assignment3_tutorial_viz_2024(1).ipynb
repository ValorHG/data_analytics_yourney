# %% [markdown]
# # Assignment 3 - Extra – Visualisation
#
# In order to effectively interpret the topic models it is necessary to employ visualisation methods.
#
# However, visualisations are often very hard to code. Therefore we provide you with some methods you can use to visualize your topic models.
#
# This notebook will show you how to use these methods and which input you have to provide to make them work.
#
# The visualisations employed in this notebook were inspired by:
# - https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/

# %%
from viz import show_sentences, show_top_k_topics, show_topic_distributions, show_topic_weights_and_counts, show_topic_wordclouds, show_wordcounts_and_topics
import pandas as pd

# %%
df_sentence_results = pd.read_csv("data/viz_example_sentence_results.csv", index_col=0)
col_sent_id, col_sent, col_sent_weights, col_topic_id, col_topic, col_topic_score, col_sent_len, col_topic_len = df_sentence_results.columns
df_sentence_results
# Out:
#       sent_id                                           sentence  \
# 0           0  ('redenen', 'anderhalve', 'meter-maatregel', '...
# 1           0  ('redenen', 'anderhalve', 'meter-maatregel', '...
# 2           0  ('redenen', 'anderhalve', 'meter-maatregel', '...
# 3           0  ('redenen', 'anderhalve', 'meter-maatregel', '...
# 4           0  ('redenen', 'anderhalve', 'meter-maatregel', '...
# ...       ...                                                ...
# 5263      877  ('zwembaden', 'open', 'schoolkinderen', 'weini...
# 5264      877  ('zwembaden', 'open', 'schoolkinderen', 'weini...
# 5265      877  ('zwembaden', 'open', 'schoolkinderen', 'weini...
# 5266      877  ('zwembaden', 'open', 'schoolkinderen', 'weini...
# 5267      877  ('zwembaden', 'open', 'schoolkinderen', 'weini...
#
#                                        col_sent_weights  topic_id  \
# 0     (0.033914, 0.028602174, 0.028153636, 0.0274458...         0
# 1     (0.039785545, 0.032295972, 0.03028803, 0.02946...         1
# 2     (0.034454267, 0.031294756, 0.030406108, 0.0291...         2
# 3     (0.06256152, 0.045397848, 0.0436387, 0.0366529...         3
# 4     (0.052543167, 0.052527025, 0.042577792, 0.0393...         4
# ...                                                 ...       ...
# 5263  (0.039785545, 0.032295972, 0.03028803, 0.02946...         1
# 5264  (0.034454267, 0.031294756, 0.030406108, 0.0291...         2
# 5265  (0.06256152, 0.045397848, 0.0436387, 0.0366529...         3
# 5266  (0.052543167, 0.052527025, 0.042577792, 0.0393...         4
# 5267  (0.040056493, 0.03837436, 0.035500564, 0.02939...         5
#
#                                                   topic  topic_score  \
# 0     ('anderhalve', 'jaar', 'jij', 'meter', 'alleen...     0.685066
# 1     ('m', 'normaal', 'we', 'lockdown', 'houden', '...     0.063457
# 2     ('houden', 'afstand', 'gewoon', 'wel', 'mensen...     0.062821
# 3     ('rt', 'beter', 'corona', 'minder', 'meter', '...     0.063524
# 4     ('kans', 'meter', '#anderhalvemetersamenleving...     0.062392
# ...                                                 ...          ...
# 5263  ('m', 'normaal', 'we', 'lockdown', 'houden', '...     0.051725
# 5264  ('houden', 'afstand', 'gewoon', 'wel', 'mensen...     0.538462
# 5265  ('rt', 'beter', 'corona', 'minder', 'meter', '...     0.252591
# 5266  ('kans', 'meter', '#anderhalvemetersamenleving...     0.053114
# 5267  ('we', 'moeten', 'waar', 'elkaar', 'regel', 'b...     0.052441
#
#       len_sent  len_topic
# 0            9         10
# 1            9         10
# 2            9         10
# 3            9         10
# 4            9         10
# ...        ...        ...
# 5263        24         10
# 5264        24         10
# 5265        24         10
# 5266        24         10
# 5267        24         10
#
# [5268 rows x 8 columns]

# %%
df_word_results = pd.read_csv("data/viz_example_word_results.csv", index_col=0)
_, col_word, _, _ = df_word_results.columns
df_word_results
# Out:
#        sent_id             word  topic_id  topic_score
# 0            0       anderhalve         0     0.032462
# 1            0       anderhalve         2     0.018094
# 2            0       anderhalve         3     0.013445
# 3            0       anderhalve         5     0.012980
# 4            0         lockdown         1     0.028340
# ...        ...              ...       ...          ...
# 13003      877           houden         5     0.022165
# 13004      877           moeten         5     0.037083
# 13005      877  #stopdelockdown         4     0.037814
# 13006      877           minder         3     0.034883
# 13007      877             open         2     0.013798
#
# [13008 rows x 4 columns]

# %%
df_corpus = pd.read_csv("data/viz_example_corpus.csv", index_col=0)
df_corpus
# Out:
#       sent_id  word_id             word     value
# 0           0        0       anderhalve  0.486108
# 1           0        1         lockdown  0.436782
# 2           0        2              via  0.756915
# 3           1        3         allemaal  0.381151
# 4           1        4           corona  0.331312
# ...       ...      ...              ...       ...
# 5473      877       13           houden  0.193048
# 5474      877       30           moeten  0.401880
# 5475      877       48  #stopdelockdown  0.477286
# 5476      877       84           minder  0.552411
# 5477      877      129             open  0.507209
#
# [5478 rows x 4 columns]

# %%
df_topics = pd.read_csv("data/viz_example_topics.csv", index_col=0)
df_topics.head()
# Out:
#    topic_id        word  topic_score
# 0         0  anderhalve     0.033914
# 1         0        jaar     0.028602
# 2         0         jij     0.028154
# 3         0       meter     0.027446
# 4         0      alleen     0.026340

# %%
tmp = list(df_corpus.groupby("sent_id"))
corpus = [(sent_id, df_sent[["word_id", "word"]].values) for sent_id, df_sent in tmp]
corpus[:3]
# Out:
# [(0,
#   array([[0, 'anderhalve'],
#          [1, 'lockdown'],
#          [2, 'via']], dtype=object)),
#  (1,
#   array([[3, 'allemaal'],
#          [4, 'corona'],
#          [5, 'gewoon'],
#          [6, 'meter'],
#          [7, 'vooral'],
#          [8, 'week'],
#          [9, 'zie']], dtype=object)),
#  (2,
#   array([[6, 'meter'],
#          [10, 'afstand'],
#          [11, 'blijven'],
#          [12, 'gaan'],
#          [13, 'houden'],
#          [14, 'mensen'],
#          [15, 'mogen'],
#          [16, 'regel'],
#          [17, 'steeds'],
#          [18, 'thuis'],
#          [19, 'wanneer'],
#          [20, 'we'],
#          [21, 'weer'],
#          [22, 'werkt']], dtype=object))]

# %%
sent_topic_index = [col_sent_id, col_sent, col_topic_id, col_topic]
df_m_dom_topics = df_sentence_results.groupby(sent_topic_index).sum().reset_index().groupby(col_sent_id).apply(
    lambda df: df[df[col_topic_score] == df[col_topic_score].max()]).sort_values(col_topic_score,
                                                                                 ascending=False).set_index("sent_id")
df_m_dom_topics["sent_id"] = df_m_dom_topics.index
df_m_dom_topics
# Out:
# /var/folders/r2/nks6m3cn0597rjgp_gldv6pr0000gn/T/ipykernel_49004/1097905572.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_m_dom_topics = df_sentence_results.groupby(sent_topic_index).sum().reset_index().groupby(col_sent_id).apply(
#                                                   sentence  topic_id  \
# sent_id
# 208      ('echt', 'stomheid', 'verbaasd', 'mensen', 'af...         5
# 390      ('inklokken', 'aanwezigheidsbonus', 'weer', 'h...         2
# 458      ('we', 'allemaal', 'even', 'lief', 'supermarkt...         2
# 66       ('@arnosspot', '@bgmpaans', 'blijft', 'raadsel...         0
# 58       ('@aniekvbreugel', 'social', 'distancing', 'nl...         2
# ...                                                    ...       ...
# 214      ('anderhalvemeterkantoor', 'inrichten', 'onmog...         3
# 447      ('kijkt', 'niemand', 'foto', 'pvdt', 'schreeuw...         2
# 447      ('kijkt', 'niemand', 'foto', 'pvdt', 'schreeuw...         0
# 214      ('anderhalvemeterkantoor', 'inrichten', 'onmog...         2
# 447      ('kijkt', 'niemand', 'foto', 'pvdt', 'schreeuw...         1
#
#                                                      topic  \
# sent_id
# 208      ('we', 'moeten', 'waar', 'elkaar', 'regel', 'b...
# 390      ('houden', 'afstand', 'gewoon', 'wel', 'mensen...
# 458      ('houden', 'afstand', 'gewoon', 'wel', 'mensen...
# 66       ('anderhalve', 'jaar', 'jij', 'meter', 'alleen...
# 58       ('houden', 'afstand', 'gewoon', 'wel', 'mensen...
# ...                                                    ...
# 214      ('rt', 'beter', 'corona', 'minder', 'meter', '...
# 447      ('houden', 'afstand', 'gewoon', 'wel', 'mensen...
# 447      ('anderhalve', 'jaar', 'jij', 'meter', 'alleen...
# 214      ('houden', 'afstand', 'gewoon', 'wel', 'mensen...
# 447      ('m', 'normaal', 'we', 'lockdown', 'houden', '...
#
#                                           col_sent_weights  topic_score  \
# sent_id
# 208      (0.040056493, 0.03837436, 0.035500564, 0.02939...     0.820304
# 390      (0.034454267, 0.031294756, 0.030406108, 0.0291...     0.805329
# 458      (0.034454267, 0.031294756, 0.030406108, 0.0291...     0.802167
# 66       (0.033914, 0.028602174, 0.028153636, 0.0274458...     0.801168
# 58       (0.034454267, 0.031294756, 0.030406108, 0.0291...     0.799666
# ...                                                    ...          ...
# 214      (0.06256152, 0.045397848, 0.0436387, 0.0366529...     0.166667
# 447      (0.034454267, 0.031294756, 0.030406108, 0.0291...     0.166667
# 447      (0.033914, 0.028602174, 0.028153636, 0.0274458...     0.166667
# 214      (0.034454267, 0.031294756, 0.030406108, 0.0291...     0.166667
# 447      (0.039785545, 0.032295972, 0.03028803, 0.02946...     0.166667
#
#          len_sent  len_topic  sent_id
# sent_id
# 208            25         10      208
# 390            19         10      390
# 458            25         10      458
# 66             26         10       66
# 58             26         10       58
# ...           ...        ...      ...
# 214             4         10      214
# 447            15         10      447
# 447            15         10      447
# 214             4         10      214
# 447            15         10      447
#
# [888 rows x 8 columns]

# %%
show_top_k_topics(df_m_dom_topics)

# %%
show_topic_distributions(df_m_dom_topics, col_sent_len="len_sent")
# Out:
# /Users/Li000199/Library/CloudStorage/OneDrive-UniversiteitUtrecht/Teaching/APML/tutorials/tutorial 3/viz.py:276: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sent_lens, color="black", shade=False, ax=ax.twinx())
# /Users/Li000199/Library/CloudStorage/OneDrive-UniversiteitUtrecht/Teaching/APML/tutorials/tutorial 3/viz.py:276: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sent_lens, color="black", shade=False, ax=ax.twinx())
# /Users/Li000199/Library/CloudStorage/OneDrive-UniversiteitUtrecht/Teaching/APML/tutorials/tutorial 3/viz.py:276: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sent_lens, color="black", shade=False, ax=ax.twinx())
# /Users/Li000199/Library/CloudStorage/OneDrive-UniversiteitUtrecht/Teaching/APML/tutorials/tutorial 3/viz.py:276: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sent_lens, color="black", shade=False, ax=ax.twinx())
# /Users/Li000199/Library/CloudStorage/OneDrive-UniversiteitUtrecht/Teaching/APML/tutorials/tutorial 3/viz.py:276: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sent_lens, color="black", shade=False, ax=ax.twinx())

# %%
topics = df_topics.groupby(col_topic_id).apply(
    lambda df: df.set_index(col_word).to_dict("dict")[col_topic_score]).to_dict()
show_topic_wordclouds(df_m_dom_topics, topics)
# Out:
# /var/folders/r2/nks6m3cn0597rjgp_gldv6pr0000gn/T/ipykernel_47708/3142614095.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   topics = df_topics.groupby(col_topic_id).apply(

# %%
show_wordcounts_and_topics(topics, df_corpus["word"].values)
# Out:
# /Users/Li000199/Library/CloudStorage/OneDrive-UniversiteitUtrecht/Teaching/APML/tutorials/tutorial 3/viz.py:183: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_word_dominant_topics.loc[df_word_dominant_topics[col_topic_id] == topic_id, 'word'],
# /Users/Li000199/Library/CloudStorage/OneDrive-UniversiteitUtrecht/Teaching/APML/tutorials/tutorial 3/viz.py:183: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_word_dominant_topics.loc[df_word_dominant_topics[col_topic_id] == topic_id, 'word'],
# /Users/Li000199/Library/CloudStorage/OneDrive-UniversiteitUtrecht/Teaching/APML/tutorials/tutorial 3/viz.py:183: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_word_dominant_topics.loc[df_word_dominant_topics[col_topic_id] == topic_id, 'word'],
# /Users/Li000199/Library/CloudStorage/OneDrive-UniversiteitUtrecht/Teaching/APML/tutorials/tutorial 3/viz.py:183: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_word_dominant_topics.loc[df_word_dominant_topics[col_topic_id] == topic_id, 'word'],
# /Users/Li000199/Library/CloudStorage/OneDrive-UniversiteitUtrecht/Teaching/APML/tutorials/tutorial 3/viz.py:183: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_word_dominant_topics.loc[df_word_dominant_topics[col_topic_id] == topic_id, 'word'],

# %%
# # Sentence Coloring of N Sentences
tmp_cols = [col_word, col_topic_id]
indices = df_word_results.groupby(tmp_cols)[col_topic_score].transform(max) == df_word_results[col_topic_score]
word_topics_strongest = df_word_results[indices].set_index("sent_id")[tmp_cols].groupby(col_sent_id)[tmp_cols].apply(
    lambda df: df.set_index(col_word).to_dict("dict")[col_topic_id]).to_dict()
sent_topics_strongest = df_m_dom_topics[col_topic_id].to_dict()
show_sentences(sent_topics_strongest, word_topics_strongest)
# Out:
# /var/folders/r2/nks6m3cn0597rjgp_gldv6pr0000gn/T/ipykernel_47708/2464663116.py:4: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   indices = df_word_results.groupby(tmp_cols)[col_topic_score].transform(max) == df_word_results[col_topic_score]

# %%
show_topic_weights_and_counts(df_m_dom_topics)
